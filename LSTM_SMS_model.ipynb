# %% [markdown]
# <a href="https://colab.research.google.com/github/dkivrak/LSTM-Based-SMS-Classification/blob/main/LSTM_SMS_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LSTM ile SMS analizi

import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/TurkishSMSCollection.csv",on_bad_lines='skip',delimiter=";")
df.head(10)
# Out:
#                                              Message  Group GroupText
# 0                                           125 lira      2    Normal
# 1              Baskanin aksam toplantısi fenaymis :)      2    Normal
# 2                Bilal yalçnlara ne zaman gidiyoruz?      2    Normal
# 3  BiP ile mesajlarimi aninda, daha eglenceli gon...      1      Spam
# 4  DIGITURKTEN FIRSAT! SiZE OZEL YIL SONUNA KADAR...      1      Spam
# 5  İyi ya dokuz eylül iyidir arş.gör falan kovala ;)      2    Normal
# 6  İyiyim teşekkürler oturuyoruz nazarda arkadaşl...      2    Normal
# 7            Kapatamıyorun ayarlara girmem lazım :)       2    Normal
# 8                 Menüye girsem görünür mü acaba ??       2    Normal
# 9                Önemli değil hocam iyi akşamlar ;)       2    Normal

# %%
df['label']=np.where(df['Group']==1,1,0)

# %%
df.head(3)
# Out:
#                                  Message  Group GroupText  label
# 0                               125 lira      2    Normal      0
# 1  Baskanin aksam toplantısi fenaymis :)      2    Normal      0
# 2    Bilal yalçnlara ne zaman gidiyoruz?      2    Normal      0

# %%
tokenizer=Tokenizer(num_words=500)
tokenizer.fit_on_texts(df['Message'])
sequences=tokenizer.texts_to_sequences(df['Message'])

pad=pad_sequences(sequences,maxlen=20)
y=df['label'].values

x_train,x_test,y_train,y_test=train_test_split(pad,y,test_size=0.2)

model=Sequential()

model.add(Embedding(500,100,input_length=20))
model.add(LSTM(64,dropout=0.2,recurrent_dropout=0.2))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=12,batch_size=64)
# Out:
# Epoch 1/12
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.8605 - loss: 0.3959 - val_accuracy: 0.9947 - val_loss: 0.0293
# Epoch 2/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9860 - loss: 0.0471 - val_accuracy: 0.9989 - val_loss: 0.0185
# Epoch 3/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9894 - loss: 0.0320 - val_accuracy: 0.9989 - val_loss: 0.0104
# Epoch 4/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9925 - loss: 0.0219 - val_accuracy: 0.9989 - val_loss: 0.0090
# Epoch 5/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9963 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 6/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9965 - loss: 0.0107 - val_accuracy: 0.9989 - val_loss: 0.0055
# Epoch 7/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9976 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 8/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9979 - val_loss: 0.0057
# Epoch 9/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9997 - loss: 0.0041 - val_accuracy: 0.9979 - val_loss: 0.0052
# Epoch 10/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9997 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0035
# Epoch 11/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9979 - val_loss: 0.0055
# Epoch 12/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9992 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0028

# %%
tahmin="günaydın nasılsın ? bugün okula gelecek misin ?"

tahmin_array=tokenizer.texts_to_sequences([tahmin])
tahmin_array=pad_sequences(tahmin_array,maxlen=20)

model.predict(tahmin_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# array([[4.003222e-05]], dtype=float32)

# %%
model.save('sms.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
